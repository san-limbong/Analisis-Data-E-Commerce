# %% [markdown]
# # Proyek Analisis Data: Nama dataset
# - Nama: San Antonio Limbong
# - Email: sanantoniolimbong@gmail.com
# - Id Dicoding: san-limbong

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Kategori produk apa yang paling banyak dan paling sedikit terjual?
# - Bagaimana persebaran pelanggan yang kita miliki?
# - Kapan terakhir pelanggan melakukan transaksi?
# - Seberapa sering seorang pelanggan melakukan pembelian dalam beberapa bulan terakhir?
# - Berapa banyak uang yang dihabiskan pelanggan dalam beberapa bulan terakhir?

# %% [markdown]
# ## Menyiapkan semua library yang dibuthkan

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %% [markdown]
# #### 1. Customer Dataset

# %%
customers_df = pd.read_csv('customers_dataset.csv')
customers_df.sample(5)
# Out:
#                             customer_id                customer_unique_id  \
# 19501  5e152b0feca6b29b0d0016c106678bff  c91a7e9c7335c7af4b5253f72e7e42d3
# 16681  3c932993d41c2ba7c0d1027658a2fc6b  b27bf89f74c911c805548615889c28f3
# 77438  bd3416ec4a72b10772b79778916c1fb5  254a9ad117407d26a52ee780dfd5216f
# 76084  ad673cf21925de88ddf3041d4d8bbe5a  2ddad95b2fbd8773e052c39e8d3c3683
# 47950  9a0554df88040ba929121aa2f66bff47  c8639255be49cc9a738ca337bcf2833f
#
#        customer_zip_code_prefix        customer_city customer_state
# 19501                     76400               uruacu             GO
# 16681                     98125  fortaleza dos valos             RS
# 77438                     17063                bauru             SP
# 76084                     13387          nova odessa             SP
# 47950                     47810            barreiras             BA

# %% [markdown]
# #### 2. Order Item Dataset

# %%
order_items_df = pd.read_csv('order_items_dataset.csv')
order_items_df.sample(5)
# Out:
#                                order_id  order_item_id  \
# 42186  6016370c0d4a0da9c57394f85d9d11d6              1
# 33716  4c53b2ac030f08c0469e8de45af2e400              1
# 37803  55c3e087340bf45947dd9df30b3808d3              2
# 61462  8c28df1eae513694a941565b1a0a5de8              1
# 70266  a04b6ad9c324577c000835fca4587931              2
#
#                              product_id                         seller_id  \
# 42186  154e7e31ebfa092203795c972e5804a6  cc419e0650a3c5ba77189a1882b7556a
# 33716  a514c9314e6d8af09721786a8ab34c7e  d197aa8fbc64087f61984deef05f6227
# 37803  6f9be3cc1d2a7eaa92b86fde15b93ac4  6c17baf138731a4aaacc3210adf2037b
# 61462  c2bd03501cf7f4f3a1201e6069155bc0  cca3071e3e9bb7d12640c9fbe2301306
# 70266  dc9471db933efad7bf0ce685380578bd  25c5c91f63607446a97b143d2d535d31
#
#        shipping_limit_date   price  freight_value
# 42186  2017-11-14 13:30:45   23.99          14.10
# 33716  2018-06-01 17:55:41   29.60           7.87
# ...

# %% [markdown]
# #### 3. Order Dataset

# %%
orders_df = pd.read_csv('orders_dataset.csv')
orders_df.sample(5)
# Out:
#                                order_id                       customer_id  \
# 46505  20080c49efc6113a519f37b79c88c375  d923411b6904f453bb966718a08e3a2e
# 89929  fb01e8d8215d266abffb5ca379063244  0d7b6a46b67046fa56193773a361e7ac
# 72880  052ef5dcbed8fd1d4d01ba597103168e  7972adc90c55b1426a19d090b47a8a1b
# 89602  19f7b4b5c61de325dbfcf2547a700024  3290173aa17384d4003caabe134a1d3b
# 61687  2a400780d5bb01c0093169085cd3edbd  065980c7bb4853a9ff23199ac044171c
#
#       order_status order_purchase_timestamp    order_approved_at  \
# 46505    delivered      2018-05-04 21:29:11  2018-05-05 03:15:09
# 89929    delivered      2017-04-03 22:00:05  2017-04-03 22:15:14
# 72880    delivered      2017-11-12 00:03:36  2017-11-12 00:36:13
# 89602    delivered      2017-07-25 10:50:22  2017-07-27 10:45:20
# 61687    delivered      2018-07-10 21:22:55  2018-07-10 21:35:25
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# ...

# %% [markdown]
# #### 4. Produk Dataset

# %%
products_df = pd.read_csv('products_dataset.csv')
products_df.sample(5)
# Out:
#                              product_id product_category_name  \
# 20101  0f40837cdd9606e43215010f9e8fce41            brinquedos
# 27144  686476adb39d272e27b0dd7c111d3762       livros_tecnicos
# 18619  5d5472bc6ef147ff1d2ca0b78127caae          beleza_saude
# 14281  140a8324a66db81d299b24b30d93098e      moveis_decoracao
# 18237  607fc06d7055bbb7c7649810df3bc0fe          beleza_saude
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 20101                 39.0                       618.0                 1.0
# 27144                 57.0                       836.0                 1.0
# 18619                 35.0                       706.0                 1.0
# 14281                 54.0                       184.0                 2.0
# 18237                 52.0                       852.0                 1.0
#
#        product_weight_g  product_length_cm  product_height_cm  \
# 20101            1600.0               40.0               11.0
# ...

# %% [markdown]
# #### 5. Kategori Produk Dataset

# %%
categoryproducts_df = pd.read_csv('product_category_name_translation.csv')
categoryproducts_df.sample(5)
# Out:
#                 product_category_name product_category_name_english
# 59                          cine_foto                    cine_photo
# 33                   eletrodomesticos               home_appliances
# 43  construcao_ferramentas_iluminacao     construction_tools_lights
# 32                        eletronicos                   electronics
# 51                    fashion_esporte                 fashion_sport

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# #### 1. Menilai tabel `customers_df`

# %%
customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
customers_df.isna().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
print("Jumlah duplikasi: ", customers_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
customers_df.describe()
# Out:
#        customer_zip_code_prefix
# count              99441.000000
# mean               35137.474583
# std                29797.938996
# min                 1003.000000
# 25%                11347.000000
# 50%                24416.000000
# 75%                58900.000000
# max                99990.000000

# %% [markdown]
# #### 2. Menilai tabel `order_items_df`

# %%
order_items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
order_items_df.isna().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %%
print("Jumlah duplikasi: ", order_items_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
order_items_df.describe()
# Out:
#        order_item_id          price  freight_value
# count  112650.000000  112650.000000  112650.000000
# mean        1.197834     120.653739      19.990320
# std         0.705124     183.633928      15.806405
# min         1.000000       0.850000       0.000000
# 25%         1.000000      39.900000      13.080000
# 50%         1.000000      74.990000      16.260000
# 75%         1.000000     134.900000      21.150000
# max        21.000000    6735.000000     409.680000

# %% [markdown]
# #### 3. Menilai tabel `orders_df`

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
orders_df.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %% [markdown]
# Pada tahapan ini menampilkan hasil missing value dengan jumlah yang cukup banyak

# %%
print("Jumlah duplikasi: ", orders_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
orders_df.describe()
# Out:
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
#
#        order_status order_purchase_timestamp    order_approved_at  \
# count         99441                    99441                99281
# unique            8                    98875                90733
# top       delivered      2018-04-11 10:48:14  2018-02-27 04:31:10
# freq          96478                        3                    9
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# count                         97658                         96476
# unique                        81018                         95664
# ...

# %% [markdown]
# #### 4. Menilai tabel `products_df`

# %%
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
products_df.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %% [markdown]
# Berdasarkan hasil tersebut, terdapat banyak records yang memiliki missing value

# %%
print("Jumlah duplikasi: ", products_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
products_df.describe()
# Out:
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# count         32341.000000                32341.000000        32341.000000
# mean             48.476949                  771.495285            2.188986
# std              10.245741                  635.115225            1.736766
# min               5.000000                    4.000000            1.000000
# 25%              42.000000                  339.000000            1.000000
# 50%              51.000000                  595.000000            1.000000
# 75%              57.000000                  972.000000            3.000000
# max              76.000000                 3992.000000           20.000000
#
#        product_weight_g  product_length_cm  product_height_cm  \
# count      32949.000000       32949.000000       32949.000000
# mean        2276.472488          30.815078          16.937661
# std         4282.038731          16.914458          13.637554
# ...

# %% [markdown]
# #### 5. Menilai tabel `categoryproducts_df`

# %%
categoryproducts_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_category_name          71 non-null     object
#  1   product_category_name_english  71 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB

# %%
categoryproducts_df.isna().sum()
# Out:
# product_category_name            0
# product_category_name_english    0
# dtype: int64

# %%
print("Jumlah duplikasi: ", categoryproducts_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
categoryproducts_df.describe()
# Out:
#        product_category_name product_category_name_english
# count                     71                            71
# unique                    71                            71
# top             beleza_saude                 health_beauty
# freq                       1                             1

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# #### Membersihkan missing value tabel `orders_df`

# %%
orders_df.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
orders_df[orders_df.order_approved_at.isna()].head(3)
# Out:
#                               order_id                       customer_id  \
# 1130  00b1cb0320190ca0daa2c88b35206009  3532ba38a3fd242259a514ac2b6ae6b6
# 1801  ed3efbd3a87bea76c2812c66a0b32219  191984a8ba4cbb2145acb4fe35b69664
# 1868  df8282afe61008dc26c6c31011474d02  aa797b187b5466bc6925aaaa4bb3bed1
#
#      order_status order_purchase_timestamp order_approved_at  \
# 1130     canceled      2018-08-28 15:26:39               NaN
# 1801     canceled      2018-09-20 13:54:16               NaN
# 1868     canceled      2017-03-04 12:14:30               NaN
#
#      order_delivered_carrier_date order_delivered_customer_date  \
# 1130                          NaN                           NaN
# 1801                          NaN                           NaN
# 1868                          NaN                           NaN
#
#      order_estimated_delivery_date
# 1130           2018-09-12 00:00:00
# 1801           2018-10-17 00:00:00
# 1868           2017-04-10 00:00:00

# %%
orders_df[orders_df.order_delivered_carrier_date.isna()].head(3)
# Out:
#                              order_id                       customer_id  \
# 6    136cce7faa42fdb2cefd53fdc79a6098  ed0271e0b7da060a393796590e7b737a
# 103  0760a852e4e9d89eb77bf631eaaf1c84  d2a79636084590b7465af8ab374a8cf5
# 128  15bed8e2fec7fdbadb186b57c46c92f2  f3f0e613e0bdb9c7cee75504f0f90679
#
#     order_status order_purchase_timestamp    order_approved_at  \
# 6       invoiced      2017-04-11 12:22:08  2017-04-13 13:25:17
# 103     invoiced      2018-08-03 17:44:42  2018-08-07 06:15:14
# 128   processing      2017-09-03 14:22:03  2017-09-03 14:30:09
#
#     order_delivered_carrier_date order_delivered_customer_date  \
# 6                            NaN                           NaN
# 103                          NaN                           NaN
# 128                          NaN                           NaN
#
#     order_estimated_delivery_date
# 6             2017-05-09 00:00:00
# 103           2018-08-21 00:00:00
# 128           2017-10-03 00:00:00

# %%
orders_df[orders_df.order_delivered_customer_date.isna()].head(3)
# Out:
#                              order_id                       customer_id  \
# 6    136cce7faa42fdb2cefd53fdc79a6098  ed0271e0b7da060a393796590e7b737a
# 44   ee64d42b8cf066f35eac1cf57de1aa85  caded193e8e47b8362864762a83db3c5
# 103  0760a852e4e9d89eb77bf631eaaf1c84  d2a79636084590b7465af8ab374a8cf5
#
#     order_status order_purchase_timestamp    order_approved_at  \
# 6       invoiced      2017-04-11 12:22:08  2017-04-13 13:25:17
# 44       shipped      2018-06-04 16:44:48  2018-06-05 04:31:18
# 103     invoiced      2018-08-03 17:44:42  2018-08-07 06:15:14
#
#     order_delivered_carrier_date order_delivered_customer_date  \
# 6                            NaN                           NaN
# 44           2018-06-05 14:32:00                           NaN
# 103                          NaN                           NaN
#
#     order_estimated_delivery_date
# 6             2017-05-09 00:00:00
# 44            2018-06-28 00:00:00
# 103           2018-08-21 00:00:00

# %% [markdown]
# Berdasarkan ketiga pertanyaan analisis terakhir,digunakan bulan (waktu) sebagai analisa parameternya. Namun pada kondisi ini, data yang digunakan bersifat aktual, maka penggunaan modifikasi imputasi untuk cleaning data, menurut saya kurang cocok. Hal tersebut akan mempengaruhi realibilitas data. Maka solusi yang ditawarkan adalah dengan melakukan drop terhadap missing value. Namun perlu mempertimbangkan jumlah records yang tersedia pada dataframe.

# %% [markdown]
# Kondisi Pra-Cleaning Data tabel `orders_df`

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
orders_df.shape ## Menghitung Jumlah baris dan kolom pada tabel
# Out:
# (99441, 8)

# %% [markdown]
# Drop Missing Value tabel `orders_df`

# %%
orders_df.dropna(axis=0, inplace=True)

# %%
print(orders_df.shape)
orders_df.info()
# Out:
# (96461, 8)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 96461 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       96461 non-null  object
#  1   customer_id                    96461 non-null  object
#  2   order_status                   96461 non-null  object
#  3   order_purchase_timestamp       96461 non-null  object
#  4   order_approved_at              96461 non-null  object
#  5   order_delivered_carrier_date   96461 non-null  object
#  6   order_delivered_customer_date  96461 non-null  object
#  7   order_estimated_delivery_date  96461 non-null  object
# dtypes: object(8)
# memory usage: 6.6+ MB

# %%
orders_df.isna().sum()
# Out:
# order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_carrier_date     0
# order_delivered_customer_date    0
# order_estimated_delivery_date    0
# dtype: int64

# %% [markdown]
# #### Membersihkan missing value tabel `products_df`

# %%
products_df.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
products_df[products_df.product_category_name.isna()]
# Out:
#                              product_id product_category_name  \
# 105    a41e356c76fab66334f36de622ecbd3a                   NaN
# 128    d8dee61c2034d6d075997acef1870e9b                   NaN
# 145    56139431d72cd51f19eb9f7dae4d1617                   NaN
# 154    46b48281eb6d663ced748f324108c733                   NaN
# 197    5fb61f482620cb672f5e586bb132eae9                   NaN
# ...                                 ...                   ...
# 32515  b0a0c5dd78e644373b199380612c350a                   NaN
# 32589  10dbe0fbaa2c505123c17fdc34a63c56                   NaN
# 32616  bd2ada37b58ae94cc838b9c0569fecd8                   NaN
# 32772  fa51e914046aab32764c41356b9d4ea4                   NaN
# 32852  c4ceee876c82b8328e9c293fa0e1989b                   NaN
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 105                    NaN                         NaN                 NaN
# ...

# %%
products_df[products_df.product_length_cm.isna()]
# Out:
#                              product_id product_category_name  \
# 8578   09ff539a621711667c43eba6a3bd8466                 bebes
# 18851  5eb564652db742ff8f28759cd8d2652a                   NaN
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 8578                  60.0                       865.0                 3.0
# 18851                  NaN                         NaN                 NaN
#
#        product_weight_g  product_length_cm  product_height_cm  \
# 8578                NaN                NaN                NaN
# 18851               NaN                NaN                NaN
#
#        product_width_cm
# 8578                NaN
# 18851               NaN

# %% [markdown]
# Hasil output tersebut menampilkan missing value yang terdapat pada informasi produk, sehingga menurut analisa tidak dapat dilakukan imputasi data karena akan mempengaruhi reliabilitas data. Maka dari itu solusi yang ditawarkan adalah melakukan drop terhadap records tersebut sama seperti persoalan sebelumnya

# %%
print(products_df.shape)
products_df.info()
# Out:
# (32951, 9)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %% [markdown]
# Setelah dilakukan drop terhadap missing value

# %%
products_df.dropna(axis=0, inplace=True)
print(products_df.shape)
products_df.info()
# Out:
# (32340, 9)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32340 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32340 non-null  object
#  1   product_category_name       32340 non-null  object
#  2   product_name_lenght         32340 non-null  float64
#  3   product_description_lenght  32340 non-null  float64
#  4   product_photos_qty          32340 non-null  float64
#  5   product_weight_g            32340 non-null  float64
#  6   product_length_cm           32340 non-null  float64
#  7   product_height_cm           32340 non-null  float64
#  8   product_width_cm            32340 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.5+ MB

# %%
products_df.isna().sum()
# Out:
# product_id                    0
# product_category_name         0
# product_name_lenght           0
# product_description_lenght    0
# product_photos_qty            0
# product_weight_g              0
# product_length_cm             0
# product_height_cm             0
# product_width_cm              0
# dtype: int64

# %% [markdown]
# #### Memperbaiki tipe data tabel `orders_df`

# %%
datetime_columns = ["order_purchase_timestamp", "order_approved_at",
                   "order_delivered_carrier_date", "order_delivered_customer_date",
                   "order_estimated_delivery_date"]

for column in datetime_columns:
  orders_df[column] = pd.to_datetime(orders_df[column])

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 96461 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       96461 non-null  object
#  1   customer_id                    96461 non-null  object
#  2   order_status                   96461 non-null  object
#  3   order_purchase_timestamp       96461 non-null  datetime64[ns]
#  4   order_approved_at              96461 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   96461 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96461 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  96461 non-null  datetime64[ns]
# dtypes: datetime64[ns](5), object(3)
# memory usage: 6.6+ MB

# %%
orders_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore `products_df` dan `categoryproducts_df`

# %%
products_category = pd.merge(
    left=products_df,
    right=categoryproducts_df,
    how="left",
    left_on="product_category_name",
    right_on="product_category_name"
)
products_category.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm  \
# 0             225.0               16.0               10.0              14.0
# ...

# %%
products_category.isna().sum()
# Out:
# product_id                        0
# product_category_name             0
# product_name_lenght               0
# product_description_lenght        0
# product_photos_qty                0
# product_weight_g                  0
# product_length_cm                 0
# product_height_cm                 0
# product_width_cm                  0
# product_category_name_english    13
# dtype: int64

# %%
products_category[products_category.product_category_name_english.isna()]
# Out:
#                              product_id  \
# 1581   0105b5323d24fc655f73052694dbbb3a
# 5703   6fd83eb3e0799b775e4f946bd66657c0
# 7176   5d923ead886c44b86845f69e50520c3e
# 7326   6727051471a0fc4a0e7737b57bff2549
# 8647   bed164d9d628cf0593003389c535c6e0
# 10822  1220978a08a6b29a202bc015b18250e9
# 13995  ae62bb0f95af63d64eae5f93dddea8d3
# 15874  1954739d84629e7323a4295812a3e0ec
# 16608  dbe520fb381ad695a7e1f2807d20c765
# 17459  c7a3f1a7f9eef146cc499368b578b884
# 18251  7afdd65f79f63819ff5bee328843fa37
# 26397  a4756663d007b0cd1af865754d08d968
# 29369  cb9d764f38ee4d0c00af64d5c388f837
#
#                                product_category_name  product_name_lenght  \
# 1581                                        pc_gamer                 59.0
# 5703   portateis_cozinha_e_preparadores_de_alimentos                 52.0
# 7176   portateis_cozinha_e_preparadores_de_alimentos                 58.0
# 7326                                        pc_gamer                 60.0
# ...

# %% [markdown]
# Berdasarkan hasil tersebut tidak ditemukan hasil translasi bahasa inggris terhadap produk dengan kategori `pc_gamer` dan `portateis_cozinha_e_preparadores_de_alimentos`. Maka dari itu akan dilakukan penanganan missing value dengan menggunakan bahasa orisinalnya kembali

# %%
products_category.loc[products_category.product_category_name == 'pc_gamer', 'product_category_name_english'] = 'pc_gamer'
products_category.loc[products_category.product_category_name == 'portateis_cozinha_e_preparadores_de_alimentos'
                 , 'product_category_name_english'] = 'portateis_cozinha_e_preparadores_de_alimentos'

products_category.isna().sum()
# Out:
# product_id                       0
# product_category_name            0
# product_name_lenght              0
# product_description_lenght       0
# product_photos_qty               0
# product_weight_g                 0
# product_length_cm                0
# product_height_cm                0
# product_width_cm                 0
# product_category_name_english    0
# dtype: int64

# %%
products_category = products_category[['product_id', 'product_category_name', 'product_category_name_english']]
products_category.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#   product_category_name_english
# 0                     perfumery
# 1                           art
# 2                sports_leisure
# 3                          baby
# 4                    housewares

# %% [markdown]
# ### Explore `customer_df`, `orders_df` dan `order_items_df`

# %%
customers_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
drop_cols = ['customer_unique_id','customer_zip_code_prefix','customer_state']
customers_df.drop(drop_cols, inplace=True, axis=1)
print(customers_df.shape)
customers_df.head()
# Out:
# (99441, 2)
#                         customer_id          customer_city
# 0  06b8999e2fba1a1fbc88172c00ba8bc7                 franca
# 1  18955e83d337fd6b2def6b18a428ac77  sao bernardo do campo
# 2  4e7b3e00288586ebd08712fdd0374a03              sao paulo
# 3  b2b6027bc5c5109e529d4dc6358b12c3        mogi das cruzes
# 4  4f2d8ab171c80ec8364f7c12e35b23ad               campinas

# %%
orders_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
drop_col = ['order_status','order_approved_at','order_approved_at','order_delivered_carrier_date','order_delivered_customer_date','order_estimated_delivery_date']
orders_df.drop(drop_col, inplace=True, axis=1)
print(orders_df.shape)
orders_df.head()
# Out:
# (96461, 3)
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_purchase_timestamp
# 0      2017-10-02 10:56:33
# 1      2018-07-24 20:41:37
# 2      2018-08-08 08:38:49
# 3      2017-11-18 19:28:06
# 4      2018-02-13 21:18:39

# %%
order_items_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
drops_cols = ['order_item_id','seller_id','freight_value','shipping_limit_date']
order_items_df.drop(drops_cols, inplace=True, axis=1)
print(order_items_df.shape)
order_items_df.head()
# Out:
# (112650, 3)
#                            order_id                        product_id   price
# 0  00010242fe8c5a6d1ba2dd792cb16214  4244733e06e7ecb4970a6e2683c13e61   58.90
# 1  00018f77f2f0320c557190d7a144bdd3  e5f2d52b802189ee658865ca93d83a8f  239.90
# 2  000229ec398224ef6ca0657da4fc703e  c777355d18b72b67abbeef9df44fd0fd  199.00
# 3  00024acbcdf0a6daa1e931b038114c75  7634da152a4610f1595efa32f14722fc   12.99
# 4  00042b26cf59d7ce69dfabb4e55b4fd9  ac6c3623068f30de03045865e4e10089  199.90

# %% [markdown]
# #### Gabungkan `orders_df` & `orders_items_df`

# %%
orderitems = pd.merge(
    left=orders_df,
    right=order_items_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
orderitems.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_purchase_timestamp                        product_id   price
# 0      2017-10-02 10:56:33  87285b34884572647811a353c7ac498a   29.99
# 1      2018-07-24 20:41:37  595fac2a385ac33a80bd5114aec74eb8  118.70
# 2      2018-08-08 08:38:49  aa4383b373c6aca5d8797843e5594415  159.90
# 3      2017-11-18 19:28:06  d0b61bfb1de832b15ba9d266ca96e5b0   45.00
# 4      2018-02-13 21:18:39  65266b2da20d04dbe00c5c2d3bb7859e   19.90

# %%
orderitems.isna().sum()
# Out:
# order_id                    0
# customer_id                 0
# order_purchase_timestamp    0
# product_id                  0
# price                       0
# dtype: int64

# %% [markdown]
# #### Gabungkan `customers_df` dan `ordersitems`

# %%
customerorders = pd.merge(
    left=customers_df,
    right=orderitems,
    how="right",
    left_on="customer_id",
    right_on="customer_id"
)
customerorders.head()
# Out:
#                         customer_id            customer_city  \
# 0  9ef432eb6251297304e76186b10a928d                sao paulo
# 1  b0830fb4747a6c6d20dea0b8c802d7ef                barreiras
# 2  41ce2a54c0b03bf3443c3d931a367089               vianopolis
# 3  f88197465ea7920adcdbec7375364d82  sao goncalo do amarante
# 4  8ab97904e6daea8866dbdbc4fb7aad2c              santo andre
#
#                            order_id order_purchase_timestamp  \
# 0  e481f51cbdc54678b7cc49136f2d6af7      2017-10-02 10:56:33
# 1  53cdb2fc8bc7dce0b6741e2150273451      2018-07-24 20:41:37
# 2  47770eb9100c2d0c44946d9cf07ec65d      2018-08-08 08:38:49
# 3  949d5b44dbf5de918fe9c16f97b45f8a      2017-11-18 19:28:06
# 4  ad21c59c0840e6cb83a9ceb5573f8159      2018-02-13 21:18:39
#
#                          product_id   price
# 0  87285b34884572647811a353c7ac498a   29.99
# 1  595fac2a385ac33a80bd5114aec74eb8  118.70
# 2  aa4383b373c6aca5d8797843e5594415  159.90
# 3  d0b61bfb1de832b15ba9d266ca96e5b0   45.00
# ...

# %%
customerorders.isna().sum()
# Out:
# customer_id                 0
# customer_city               0
# order_id                    0
# order_purchase_timestamp    0
# product_id                  0
# price                       0
# dtype: int64

# %% [markdown]
# ### Explore all data

# %% [markdown]
# #### Menghubungkan semua data

# %%
all_df = pd.merge(
    left=customerorders,
    right=products_category,
    how="inner",
    left_on="product_id",
    right_on="product_id"
)
all_df.head()
# Out:
#                         customer_id  customer_city  \
# 0  9ef432eb6251297304e76186b10a928d      sao paulo
# 1  a20e8105f23924cd00833fd87daa0831      sao paulo
# 2  26c7ac168e1433912a51b924fbd34d34      sao paulo
# 3  53904ddbea91e1e92b2b3f1d09a7af86  florianopolis
# 4  b0830fb4747a6c6d20dea0b8c802d7ef      barreiras
#
#                            order_id order_purchase_timestamp  \
# 0  e481f51cbdc54678b7cc49136f2d6af7      2017-10-02 10:56:33
# 1  128e10d95713541c87cd1a2e48201934      2017-08-15 18:29:31
# 2  0e7e841ddf8f8f2de2bad69267ecfbcf      2017-08-02 18:24:47
# 3  bfc39df4f36c3693ff3b63fcbea9e90a      2017-10-23 23:26:46
# 4  53cdb2fc8bc7dce0b6741e2150273451      2018-07-24 20:41:37
#
#                          product_id   price  product_category_name  \
# 0  87285b34884572647811a353c7ac498a   29.99  utilidades_domesticas
# 1  87285b34884572647811a353c7ac498a   29.99  utilidades_domesticas
# 2  87285b34884572647811a353c7ac498a   29.99  utilidades_domesticas
# ...

# %%
all_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 108643 entries, 0 to 108642
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   customer_id                    108643 non-null  object
#  1   customer_city                  108643 non-null  object
#  2   order_id                       108643 non-null  object
#  3   order_purchase_timestamp       108643 non-null  datetime64[ns]
#  4   product_id                     108643 non-null  object
#  5   price                          108643 non-null  float64
#  6   product_category_name          108643 non-null  object
#  7   product_category_name_english  108643 non-null  object
# dtypes: datetime64[ns](1), float64(1), object(6)
# memory usage: 7.5+ MB

# %%
all_df.isna().sum()
# Out:
# customer_id                      0
# customer_city                    0
# order_id                         0
# order_purchase_timestamp         0
# product_id                       0
# price                            0
# product_category_name            0
# product_category_name_english    0
# dtype: int64

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Kategori produk apa yang paling banyak dan paling sedikit terjual?

# %%
sum_order_items_df = all_df.groupby("product_category_name_english").order_id.nunique().sort_values(ascending=False).reset_index()
sum_order_items_df.rename(columns={
    "product_category_name_english": "product_category_name",
    "order_id" : "product_count"
}, inplace=True)
sum_order_items_df.head(10)
# Out:
#    product_category_name  product_count
# 0         bed_bath_table           9271
# 1          health_beauty           8649
# 2         sports_leisure           7528
# 3  computers_accessories           6529
# 4        furniture_decor           6303
# 5             housewares           5743
# 6          watches_gifts           5493
# 7              telephony           4092
# 8                   auto           3809
# 9                   toys           3804

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(24, 6))

colors = ["#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]

sns.barplot(x="product_count", y="product_category_name", data=sum_order_items_df.head(5), palette=colors, ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("Best Performing Product", loc="center", fontsize=18)
ax[0].tick_params(axis ='y', labelsize=15)

sns.barplot(x="product_count", y="product_category_name", data=sum_order_items_df.sort_values(by="product_count", ascending=True).head(5), palette=colors, ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].invert_xaxis()
ax[1].yaxis.set_label_position("right")
ax[1].yaxis.tick_right()
ax[1].set_title("Worst Performing Product", loc="center", fontsize=18)
ax[1].tick_params(axis='y', labelsize=15)

plt.suptitle("Best and Worst Performing Product by Number of Sales", fontsize=20)
plt.show()

# %% [markdown]
# ### Pertanyaan 2: Bagaimana persebaran pelanggan yang kita miliki?

# %%
all_df.groupby(by="customer_city").order_id.nunique().sort_values(ascending=False)
# Out:
# customer_city
# sao paulo         14811
# rio de janeiro     6498
# belo horizonte     2650
# brasilia           2042
# curitiba           1474
#                   ...
# macaubal              1
# macambira             1
# luziapolis            1
# lutecia               1
# zortea                1
# Name: order_id, Length: 4073, dtype: int64

# %%
bycity_df = all_df.groupby(by="customer_city").order_id.nunique().sort_values(ascending=False).reset_index()
bycity_df.rename(columns={
    "order_id": "order_count"
}, inplace=True)
bycity_df.head()
# Out:
#     customer_city  order_count
# 0       sao paulo        14811
# 1  rio de janeiro         6498
# 2  belo horizonte         2650
# 3        brasilia         2042
# 4        curitiba         1474

# %%
plt.figure(figsize=(10, 5))
colors_ = ["#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]
sns.barplot(
    x="order_count", 
    y="customer_city",
    data=bycity_df.sort_values(by="order_count", ascending=False).head(8),
    palette=colors_
)
plt.title("Number of Customer by City", loc="center", fontsize=15)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis='y', labelsize=12)
plt.show()

# %% [markdown]
# ### RFM Analysis

# %%
all_df.sort_values(by='order_purchase_timestamp', ascending=False).head()
# Out:
#                              customer_id       customer_city  \
# 28365   898b7fee99c4e42170ab69ba59be0a8b             limeira
# 101069  496630b6740bcca28fce9ba50d8a26ef  sao caetano do sul
# 43734   6e353700bc7bcdf6ebc15d6de16d7002            paracatu
# 58556   e60df9449653a95af4549bbfcb18a6eb            curitiba
# 58557   e60df9449653a95af4549bbfcb18a6eb            curitiba
#
#                                 order_id order_purchase_timestamp  \
# 28365   35a972d7f8436f405b56e36add1a7140      2018-08-29 15:00:37
# 101069  03ef5dedbe7492bdae72eec50764c43f      2018-08-29 14:52:00
# 43734   168626408cb32af0ffaf76711caae1dc      2018-08-29 14:18:28
# 58556   0b223d92c27432930dfe407c6aea3041      2018-08-29 14:18:23
# 58557   0b223d92c27432930dfe407c6aea3041      2018-08-29 14:18:23
#
#                               product_id   price  \
# 28365   d04857e7b4b708ee8b8b9921163edba3   84.99
# 101069  c7f27c5bef2338541c772b5776403e6a   24.90
# ...

# %%
# Buat customer_id sbg index (unique)
customer_id_mapping = {customer_id: i +1 for i, customer_id in enumerate(all_df['customer_id'].unique())}
all_df['id'] = all_df['customer_id'].map(customer_id_mapping)

rfm_df = all_df.groupby(by="id", as_index=False).agg({
    "order_purchase_timestamp": "max", #mengambil tanggal order terakhir
    "order_id": "nunique",
    "price": "sum"
})
rfm_df.columns = ["customer_id", "max_order_timestamp", "frequency", "monetary"]
rfm_df.head()
# Out:
#    customer_id max_order_timestamp  frequency  monetary
# 0            1 2017-10-02 10:56:33          1     29.99
# 1            2 2017-08-15 18:29:31          1     29.99
# 2            3 2017-08-02 18:24:47          1     29.99
# 3            4 2017-10-23 23:26:46          1     29.99
# 4            5 2018-07-24 20:41:37          1    118.70

# %%
# menghitung kapan terakhir pelanggan melakukan transaksi (hari)
rfm_df["max_order_timestamp"] = rfm_df["max_order_timestamp"].dt.date
recent_date = all_df["order_purchase_timestamp"].dt.date.max()
rfm_df["recency"] = rfm_df["max_order_timestamp"].apply(lambda x: (recent_date - x).days)
rfm_df.head()
# Out:
#    customer_id max_order_timestamp  frequency  monetary  recency
# 0            1          2017-10-02          1     29.99      331
# 1            2          2017-08-15          1     29.99      379
# 2            3          2017-08-02          1     29.99      392
# 3            4          2017-10-23          1     29.99      310
# 4            5          2018-07-24          1    118.70       36

# %%
rfm_df.drop("max_order_timestamp", axis=1, inplace=True)
rfm_df.head()
# Out:
#    customer_id  frequency  monetary  recency
# 0            1          1     29.99      331
# 1            2          1     29.99      379
# 2            3          1     29.99      392
# 3            4          1     29.99      310
# 4            5          1    118.70       36

# %%
rfm_df.describe()
# Out:
#         customer_id  frequency      monetary       recency
# count  95129.000000    95129.0  95129.000000  95129.000000
# mean   47565.000000        1.0    137.144667    238.911341
# std    27461.521216        0.0    208.909695    152.835456
# min        1.000000        1.0      0.850000      0.000000
# 25%    23783.000000        1.0     45.900000    115.000000
# 50%    47565.000000        1.0     86.000000    220.000000
# 75%    71347.000000        1.0    149.900000    349.000000
# max    95129.000000        1.0  13440.000000    713.000000

# %%
rfm_df.sort_values(by="recency", ascending=True).head(5)
# Out:
#        customer_id  frequency  monetary  recency
# 88897        88898          1     24.90        0
# 80924        80925          1     63.90        0
# 33987        33988          1    457.75        0
# 39393        39394          1     45.90        0
# 27752        27753          1     65.00        0

# %%
rfm_df.sort_values(by="frequency", ascending=False).head(5)
# Out:
#        customer_id  frequency  monetary  recency
# 0                1          1     29.99      331
# 63416        63417          1    129.99      380
# 63425        63426          1     59.99      323
# 63424        63425          1    119.98      266
# 63423        63424          1    179.97      275

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(30, 6))

colors = ["#72BCD4", "#72BCD4", "#72BCD4", "#72BCD4", "#72BCD4"]

sns.barplot(y="recency", x="customer_id", data=rfm_df.sort_values(by="recency", ascending=False).head(5), palette=colors, ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("By Recency (days)", loc="center", fontsize=18)
ax[0].tick_params(axis ='x', labelsize=15)

sns.barplot(y="frequency", x="customer_id", data=rfm_df.sort_values(by="frequency", ascending=False).head(5), palette=colors, ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].set_title("By Frequency", loc="center", fontsize=18)
ax[1].tick_params(axis='x', labelsize=15)

sns.barplot(y="monetary", x="customer_id", data=rfm_df.sort_values(by="monetary", ascending=False).head(5), palette=colors, ax=ax[2])
ax[2].set_ylabel(None)
ax[2].set_xlabel(None)
ax[2].set_title("By Monetary", loc="center", fontsize=18)
ax[2].tick_params(axis='x', labelsize=15)

plt.suptitle("Best Customer Based on RFM Parameters (customer_id)", fontsize=20)
plt.show()

# %% [markdown]
# ### Mengurutkan customer berdasarkan recency, frequency, & monetary score

# %%
rfm_df['r_rank'] = rfm_df['recency'].rank(ascending=False)
rfm_df['f_rank'] = rfm_df['frequency'].rank(ascending=True)
rfm_df['m_rank'] = rfm_df['monetary'].rank(ascending=True)

rfm_df.head()
# Out:
#    customer_id  frequency  monetary  recency   r_rank   f_rank   m_rank
# 0            1          1     29.99      331  26126.5  47565.0  13814.5
# 1            2          1     29.99      379  19657.0  47565.0  13814.5
# 2            3          1     29.99      392  17948.0  47565.0  13814.5
# 3            4          1     29.99      310  29203.0  47565.0  13814.5
# 4            5          1    118.70       36  87050.0  47565.0  61035.0

# %%
# normalizing the rank of the customers
rfm_df['r_rank_norm'] = (rfm_df['r_rank']/rfm_df['r_rank'].max())*100
rfm_df['f_rank_norm'] = (rfm_df['f_rank']/rfm_df['f_rank'].max())*100
rfm_df['m_rank_norm'] = (rfm_df['m_rank']/rfm_df['m_rank'].max())*100
 
rfm_df.drop(columns=['r_rank', 'f_rank', 'm_rank'], inplace=True)
 
rfm_df.head()
# Out:
#    customer_id  frequency  monetary  recency  r_rank_norm  f_rank_norm  \
# 0            1          1     29.99      331    27.465729        100.0
# 1            2          1     29.99      379    20.664606        100.0
# 2            3          1     29.99      392    18.868004        100.0
# 3            4          1     29.99      310    30.699929        100.0
# 4            5          1    118.70       36    91.512132        100.0
#
#    m_rank_norm
# 0    14.521860
# 1    14.521860
# 2    14.521860
# 3    14.521860
# 4    64.160246

# %%
rfm_df['RFM_score'] = 0.15*rfm_df['r_rank_norm']+0.28 * \
    rfm_df['f_rank_norm']+0.57*rfm_df['m_rank_norm']
rfm_df['RFM_score'] *= 0.05
rfm_df = rfm_df.round(2)
rfm_df[['customer_id', 'RFM_score']].head(7)
# Out:
#    customer_id  RFM_score
# 0            1       2.02
# 1            2       1.97
# 2            3       1.96
# 3            4       2.04
# 4            5       3.91
# 5            6       3.89
# 6            7       3.93

# %% [markdown]
# ### Segmentasi customer berdasarkan RFM_score

# %%
rfm_df["customer_segment"] = np.where(
    rfm_df['RFM_score'] > 4.5, "Top customers", (np.where(
        rfm_df['RFM_score'] > 4, "High value customer",(np.where(
            rfm_df['RFM_score'] > 3, "Medium value customer", np.where(
                rfm_df['RFM_score'] > 1.6, 'Low value customers', 'lost customers'))))))

rfm_df[['customer_id', 'RFM_score', 'customer_segment']].head(20)
# Out:
#     customer_id  RFM_score       customer_segment
# 0             1       2.02    Low value customers
# 1             2       1.97    Low value customers
# 2             3       1.96    Low value customers
# 3             4       2.04    Low value customers
# 4             5       3.91  Medium value customer
# 5             6       3.89  Medium value customer
# 6             7       3.93  Medium value customer
# 7             8       3.82  Medium value customer
# 8             9       3.43  Medium value customer
# 9            10       3.94  Medium value customer
# 10           11       3.86  Medium value customer
# 11           12       3.96  Medium value customer
# 12           13       3.55  Medium value customer
# 13           14       3.85  Medium value customer
# 14           15       3.89  Medium value customer
# 15           16       3.96  Medium value customer
# 16           17       3.62  Medium value customer
# 17           18       3.71  Medium value customer
# ...

# %%
customer_segment_df = rfm_df.groupby(by="customer_segment", as_index=False).customer_id.nunique()
customer_segment_df
# Out:
#         customer_segment  customer_id
# 0    High value customer        15455
# 1    Low value customers        39967
# 2  Medium value customer        33287
# 3          Top customers         5348
# 4         lost customers         1072

# %%
customer_segment_df['customer_segment'] = pd.Categorical(customer_segment_df['customer_segment'], [
    "lost customers", "Low value customers", "Medium value customer",
    "High value customer", "Top customers"
])

# %%
plt.figure(figsize=(10, 5))
colors_ = ["#72BCD4", "#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3"]

sns.barplot(
    x="customer_id", 
    y="customer_segment",
    data=customer_segment_df.sort_values(by="customer_segment", ascending=False),
    palette=colors_
)
plt.title("Number of Customer for Each Segment", loc="center", fontsize=15)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis='y', labelsize=12)
plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ### Conclution pertanyaan 1

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(24, 6))

colors = ["#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]

sns.barplot(x="product_count", y="product_category_name", data=sum_order_items_df.head(5), palette=colors, ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("Best Performing Product", loc="center", fontsize=18)
ax[0].tick_params(axis ='y', labelsize=15)

sns.barplot(x="product_count", y="product_category_name", data=sum_order_items_df.sort_values(by="product_count", ascending=True).head(5), palette=colors, ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].invert_xaxis()
ax[1].yaxis.set_label_position("right")
ax[1].yaxis.tick_right()
ax[1].set_title("Worst Performing Product", loc="center", fontsize=18)
ax[1].tick_params(axis='y', labelsize=15)

plt.suptitle("Best and Worst Performing Product by Number of Sales", fontsize=20)
plt.show()

# %% [markdown]
# Kategori produk yang paling banyak terjual adalah `bed_bath_table` sebanyak `9271 pemesanan` diikuti kategori `health_beauty` sebanyak `8649 pemesanan`. Sementara untuk kategori produk yang paling sedikit terjual adalah `security and services` yakni sebanyak `2 pemesanan`.

# %% [markdown]
# ### Conclution pertanyaan 2

# %%
plt.figure(figsize=(10, 5))
colors_ = ["#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]
sns.barplot(
    x="order_count", 
    y="customer_city",
    data=bycity_df.sort_values(by="order_count", ascending=False).head(8),
    palette=colors_
)
plt.title("Number of Customer by City", loc="center", fontsize=15)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis='y', labelsize=12)
plt.show()

# %% [markdown]
# Berdasarkan analisis yang dilakukan diketahui bahwa persebaran pelanggan ditemukan pada kota `sao paulo` dan `rio de janeiro` yang ditampilkan dengan jumlah pemesanan yang terdapat pada dataset.

# %% [markdown]
# ### Conclution pertanyaan 3, 4, dan 5

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(30, 6))

colors = ["#72BCD4", "#72BCD4", "#72BCD4", "#72BCD4", "#72BCD4"]

sns.barplot(y="recency", x="customer_id", data=rfm_df.sort_values(by="recency", ascending=False).head(5), palette=colors, ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("By Recency (days)", loc="center", fontsize=18)
ax[0].tick_params(axis ='x', labelsize=15)

sns.barplot(y="frequency", x="customer_id", data=rfm_df.sort_values(by="frequency", ascending=False).head(5), palette=colors, ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].set_title("By Frequency", loc="center", fontsize=18)
ax[1].tick_params(axis='x', labelsize=15)

sns.barplot(y="monetary", x="customer_id", data=rfm_df.sort_values(by="monetary", ascending=False).head(5), palette=colors, ax=ax[2])
ax[2].set_ylabel(None)
ax[2].set_xlabel(None)
ax[2].set_title("By Monetary", loc="center", fontsize=18)
ax[2].tick_params(axis='x', labelsize=15)

plt.suptitle("Best Customer Based on RFM Parameters (customer_id)", fontsize=20)
plt.show()

# %%
rfm_df.describe()
# Out:
#         customer_id  frequency      monetary       recency   r_rank_norm  \
# count  95129.000000    95129.0  95129.000000  95129.000000  95129.000000
# mean   47565.000000        1.0    137.144667    238.911341     50.003174
# std    27461.521216        0.0    208.909695    152.835456     28.869121
# min        1.000000        1.0      0.850000      0.000000      0.000000
# 25%    23783.000000        1.0     45.900000    115.000000     24.950000
# 50%    47565.000000        1.0     86.000000    220.000000     49.930000
# 75%    71347.000000        1.0    149.900000    349.000000     74.940000
# max    95129.000000        1.0  13440.000000    713.000000    100.000000
#
#        f_rank_norm   m_rank_norm     RFM_score
# count      95129.0  95129.000000  95129.000000
# mean         100.0     50.000662      3.200055
# std            0.0     28.867184      0.852327
# min          100.0      0.000000      1.400000
# 25%          100.0     24.910000      2.500000
# ...

# %% [markdown]
# Berdasarkan visualisasi tersebut, pelanggan terakhir melakukan transaksi yakni `0 hari`. Adapun estimasi dari seberapa sering seorang pelanggan melakukan pembelian dalam beberapa bulan terakhir adalah sebanyak `1 kali`. Uang yang dihabiskan pelanggan dalam beberapa bulan terakhir adalah sebesar `137.144667 (satuan mata uang yang digunakan)`.

# %%
all_df.to_csv("dashboard/all_data.csv", index=False)
